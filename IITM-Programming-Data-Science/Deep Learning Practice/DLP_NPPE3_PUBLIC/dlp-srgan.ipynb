png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/gt/gt_00861.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/gt/gt_00891.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/gt/gt_00254.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/gt/gt_00470.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/gt/gt_00095.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/gt/gt_00907.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/gt/gt_00114.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/gt/gt_00215.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/gt/gt_00061.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/gt/gt_00485.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/gt/gt_00418.png
# ...
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00040.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00763.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00407.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00069.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00734.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00165.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00911.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01001.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00434.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00639.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00439.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00451.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00120.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00602.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00665.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00536.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00788.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01057.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00396.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00460.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01044.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00595.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00685.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00978.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00302.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00695.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00141.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00768.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00137.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00435.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00666.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00227.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01036.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01055.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00088.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00028.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00876.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00539.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00417.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00400.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00315.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00195.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00093.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01023.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00958.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00517.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01022.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00297.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00300.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00771.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00758.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00325.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00339.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00166.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00082.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00450.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00598.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01005.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00607.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01035.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01039.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00217.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00079.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01099.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00786.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00200.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00344.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01021.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00547.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00995.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01101.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00603.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00863.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00359.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00066.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00461.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00865.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00103.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00675.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00324.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00896.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00045.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00844.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01037.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00287.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01024.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00956.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01072.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00449.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00869.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00920.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00953.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00722.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00185.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01086.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00127.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00767.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00527.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00477.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01025.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00673.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00553.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00399.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00889.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00036.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00940.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00549.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00128.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00393.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00550.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00982.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00760.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00084.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00837.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00736.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00793.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00060.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00829.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00442.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01040.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00860.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00689.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00937.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00807.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00932.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00866.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00131.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00779.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00566.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00218.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00633.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00804.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01019.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00345.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00110.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00213.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00492.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00370.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00272.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00438.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00813.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00480.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00599.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00136.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00076.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00753.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01070.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01076.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00067.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01007.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00130.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01084.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01027.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00479.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00371.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00104.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00307.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00791.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00206.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00401.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00106.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00904.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00179.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00680.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00628.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00737.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00010.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00360.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00142.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00645.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00515.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00273.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00626.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00064.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00893.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00448.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00554.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00790.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00579.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00928.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00034.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00373.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00594.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00609.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00697.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00475.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00649.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01074.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00383.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00193.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00624.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00787.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00947.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00611.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00816.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00888.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00931.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00575.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00011.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00101.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00057.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00016.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00984.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00849.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00769.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00065.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00593.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00466.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00839.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00486.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00456.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00644.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00610.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00411.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00577.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00292.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00356.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00286.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00364.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_01096.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00950.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00157.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00729.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00683.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00908.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00363.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00810.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00091.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00086.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00035.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00613.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00262.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00635.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00584.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00820.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00765.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00341.png
# /kaggle/input/dlp-jan-2025-nppe-3/archive/train/train/gt_00239.png

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.amp import autocast, GradScaler

# Dataset Classes
class LowLightDataset(Dataset):
    def __init__(self, noisy_dir, gt_dir):
        self.noisy_dir = noisy_dir
        self.gt_dir = gt_dir
        self.noisy_files = sorted(os.listdir(noisy_dir))
        self.gt_files = sorted(os.listdir(gt_dir))
        assert len(self.noisy_files) == len(self.gt_files), "Mismatch in file counts"

    def __len__(self):
        return len(self.noisy_files)

    def __getitem__(self, idx):
        noisy_path = os.path.join(self.noisy_dir, self.noisy_files[idx])
        gt_path = os.path.join(self.gt_dir, self.gt_files[idx])
        
        noisy_img = np.array(Image.open(noisy_path)) / 255.0
        gt_img = np.array(Image.open(gt_path)) / 255.0
        
        noisy_img = torch.FloatTensor(noisy_img).permute(2, 0, 1)
        gt_img = torch.FloatTensor(gt_img).permute(2, 0, 1)
        
        return noisy_img, gt_img

class TestDataset(Dataset):
    def __init__(self, test_dir):
        self.test_dir = test_dir
        self.test_files = sorted(os.listdir(test_dir))

    def __len__(self):
        return len(self.test_files)

    def __getitem__(self, idx):
        img_path = os.path.join(self.test_dir, self.test_files[idx])
        img = np.array(Image.open(img_path)) / 255.0
        img = torch.FloatTensor(img).permute(2, 0, 1)
        return img, self.test_files[idx]

# %%
# Main Execution
#base_path = "path_to_dataset"  # Replace with your dataset path
train_noisy_path = os.path.join(base_path, "train/train")
train_gt_path = os.path.join(base_path, "train/gt")
val_noisy_path = os.path.join(base_path, "val/val")
val_gt_path = os.path.join(base_path, "val/gt")
test_dir = os.path.join(base_path, "test")
output_folder = "test_outputs"
submission_csv = "submission.csv"

# %%
# Generator
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.entry = nn.Conv2d(3, 64, 3, padding=1)
        self.body = nn.Sequential(
            *[nn.Sequential(
                nn.Conv2d(64, 64, 3, padding=1),
                nn.ReLU()
            ) for _ in range(5)]
        )
        self.upscale = nn.Sequential(
            nn.Conv2d(64, 64 * 16, 3, padding=1),
            nn.PixelShuffle(4),
            nn.Conv2d(64, 1, 3, padding=1)
        )
    
    def forward(self, x):
        x = self.entry(x)
        res = self.body(x)
        return self.upscale(res + x)

# Discriminator (remove Sigmoid)
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Conv2d(1, 64, 3, stride=2, padding=1), nn.LeakyReLU(0.2),
            nn.Conv2d(64, 128, 3, stride=2, padding=1), nn.LeakyReLU(0.2),
            nn.Conv2d(128, 256, 3, stride=2, padding=1), nn.LeakyReLU(0.2),
            nn.Conv2d(256, 512, 3, stride=2, padding=1), nn.LeakyReLU(0.2),
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(512, 256), nn.LeakyReLU(0.2),
            nn.Linear(256, 1)  # Output logits, no Sigmoid
        )
    
    def forward(self, x):
        return self.model(x)

# %%
def train_sgan(train_loader, val_loader, epochs=50):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    gen = Generator().to(device)
    disc = Discriminator().to(device)
    
    print("No EDSR checkpoints found—training SRGAN from scratch")  # Since confirmed
    
    g_opt = torch.optim.Adam(gen.parameters(), lr=1e-4)
    d_opt = torch.optim.Adam(disc.parameters(), lr=1e-4)
    mse_loss = nn.MSELoss()
    bce_logits_loss = nn.BCEWithLogitsLoss()
    scaler = GradScaler('cuda')

    for epoch in range(epochs):
        gen.train()
        disc.train()
        g_loss_total, d_loss_total = 0, 0
        for noisy, gt in train_loader:
            noisy, gt = noisy.to(device), gt.to(device)
            gt_gray = torch.mean(gt, dim=1, keepdim=True)
            
            # Train Discriminator
            d_opt.zero_grad()
            with autocast('cuda'):
                real_out = disc(gt_gray)
                fake_img = gen(noisy)
                fake_out = disc(fake_img.detach())
                d_loss = bce_logits_loss(real_out, torch.ones_like(real_out)) + \
                         bce_logits_loss(fake_out, torch.zeros_like(fake_out))
            scaler.scale(d_loss).backward()
            scaler.step(d_opt)
            scaler.update()
            d_loss_total += d_loss.item()
            
            # Train Generator
            g_opt.zero_grad()
            with autocast('cuda'):
                fake_out = disc(fake_img)
                g_mse = mse_loss(fake_img, gt_gray)
                g_adv = bce_logits_loss(fake_out, torch.ones_like(fake_out))
                g_loss = 0.95 * g_mse + 0.05 * g_adv  # Adjusted weights
            scaler.scale(g_loss).backward()
            scaler.step(g_opt)
            scaler.update()
            g_loss_total += g_mse.item()
        
        avg_g_loss = g_loss_total / len(train_loader)
        print(f"Epoch {epoch+1}/{epochs}, G Loss (MSE): {avg_g_loss:.6f}")
        
        gen.eval()
        val_loss = 0
        with torch.no_grad():
            for noisy, gt in val_loader:
                noisy, gt = noisy.to(device), gt.to(device)
                with autocast('cuda'):
                    output = gen(noisy)
                    gt_gray = torch.mean(gt, dim=1, keepdim=True)
                    loss = mse_loss(output, gt_gray)
                val_loss += loss.item()
        val_mse = val_loss / len(val_loader)
        val_psnr = 10 * torch.log10(1 / torch.tensor(val_mse)).item()
        print(f"Validation Loss: {val_mse:.6f}, PSNR: {val_psnr:.2f} dB")
        
        if (epoch + 1) % 10 == 0:
            torch.save(gen.state_dict(), f"srgan_gen_epoch_{epoch+1}.pth")
    
    torch.save(gen.state_dict(), "srgan_gen_final.pth")
    return gen

# %%
# Submission Function
def generate_submission(model, test_dir, output_folder, submission_csv):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device).eval()
    os.makedirs(output_folder, exist_ok=True)
    test_dataset = TestDataset(test_dir)
    test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
    with torch.no_grad():
        for imgs, filenames in test_loader:
            imgs = imgs.to(device)
            outputs = model(imgs)
            output = outputs.squeeze(0).cpu().numpy()[0]
            output = (output * 255).clip(0, 255).astype(np.uint8)
            filename = filenames[0]
            output_path = os.path.join(output_folder, filename)
            Image.fromarray(output).save(output_path)
    data_rows = []
    for filename in os.listdir(output_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            image_path = os.path.join(output_folder, filename)
            image = Image.open(image_path).convert('L')
            image_array = np.array(image).flatten()[::8]
            image_id = filename.split('.')[0].replace('test_', 'gt_')
            data_rows.append([image_id, *image_array])
    column_names = ['ID'] + [f'pixel_{i}' for i in range(len(data_rows[0]) - 1)]
    df = pd.DataFrame(data_rows, columns=column_names)
    df.to_csv(submission_csv, index=False)
    print(f'Successfully saved to {submission_csv}')

# %%
# Main Execution
base_path = "/kaggle/input/dlp-jan-2025-nppe-3/archive"  
train_noisy_path = os.path.join(base_path, "train/train")
train_gt_path = os.path.join(base_path, "train/gt")
val_noisy_path = os.path.join(base_path, "val/val")
val_gt_path = os.path.join(base_path, "val/gt")
test_dir = os.path.join(base_path, "test")
output_folder = "test_outputs"
submission_csv = "submission.csv"

# %%
train_dataset = LowLightDataset(train_noisy_path, train_gt_path)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_dataset = LowLightDataset(val_noisy_path, val_gt_path)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# %%
model = train_sgan(train_loader, val_loader, epochs=50) #50
# Out:
# No EDSR checkpoints found—training SRGAN from scratch
# Epoch 1/50, G Loss (MSE): 0.003712
# Validation Loss: 0.000415, PSNR: 33.82 dB
# Epoch 2/50, G Loss (MSE): 0.000639
# Validation Loss: 0.000308, PSNR: 35.11 dB
# Epoch 3/50, G Loss (MSE): 0.000459
# Validation Loss: 0.000245, PSNR: 36.11 dB
# Epoch 4/50, G Loss (MSE): 0.000390
# Validation Loss: 0.000224, PSNR: 36.51 dB
# Epoch 5/50, G Loss (MSE): 0.000371
# Validation Loss: 0.000235, PSNR: 36.28 dB
# Epoch 6/50, G Loss (MSE): 0.000391
# Validation Loss: 0.000195, PSNR: 37.10 dB
# Epoch 7/50, G Loss (MSE): 0.000321
# Validation Loss: 0.000222, PSNR: 36.53 dB
# Epoch 8/50, G Loss (MSE): 0.000337
# Validation Loss: 0.000195, PSNR: 37.09 dB
# Epoch 9/50, G Loss (MSE): 0.000321
# Validation Loss: 0.000213, PSNR: 36.71 dB
# Epoch 10/50, G Loss (MSE): 0.000301
# Validation Loss: 0.000196, PSNR: 37.09 dB
# Epoch 11/50, G Loss (MSE): 0.000304
# Validation Loss: 0.000182, PSNR: 37.39 dB
# Epoch 12/50, G Loss (MSE): 0.000289
# Validation Loss: 0.000171, PSNR: 37.67 dB
# Epoch 13/50, G Loss (MSE): 0.000323
# Validation Loss: 0.000164, PSNR: 37.84 dB
# Epoch 14/50, G Loss (MSE): 0.000274
# Validation Loss: 0.000178, PSNR: 37.50 dB
# Epoch 15/50, G Loss (MSE): 0.000305
# Validation Loss: 0.000186, PSNR: 37.30 dB
# Epoch 16/50, G Loss (MSE): 0.000271
# Validation Loss: 0.000191, PSNR: 37.19 dB
# Epoch 17/50, G Loss (MSE): 0.000279
# Validation Loss: 0.000168, PSNR: 37.75 dB
# Epoch 18/50, G Loss (MSE): 0.000285
# Validation Loss: 0.000201, PSNR: 36.96 dB
# Epoch 19/50, G Loss (MSE): 0.000287
# Validation Loss: 0.000207, PSNR: 36.84 dB
# Epoch 20/50, G Loss (MSE): 0.000299
# Validation Loss: 0.000157, PSNR: 38.05 dB
# Epoch 21/50, G Loss (MSE): 0.000302
# Validation Loss: 0.000169, PSNR: 37.71 dB
# Epoch 22/50, G Loss (MSE): 0.000301
# Validation Loss: 0.000202, PSNR: 36.94 dB
# Epoch 23/50, G Loss (MSE): 0.000310
# Validation Loss: 0.000287, PSNR: 35.42 dB
# Epoch 24/50, G Loss (MSE): 0.000320
# Validation Loss: 0.000169, PSNR: 37.71 dB
# Epoch 25/50, G Loss (MSE): 0.000302
# Validation Loss: 0.000224, PSNR: 36.51 dB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-eb3f2e6b9c57> in <cell line: 1>()
# ----> 1 model = train_sgan(train_loader, val_loader, epochs=50) #50
#
# <ipython-input-29-8b36a29b94ef> in train_sgan(train_loader, val_loader, epochs)
#      16         disc.train()
#      17         g_loss_total, d_loss_total = 0, 0
# ---> 18         for noisy, gt in train_loader:
#      19             noisy, gt = noisy.to(device), gt.to(device)
#      20             gt_gray = torch.mean(gt, dim=1, keepdim=True)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     699                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700                 self._reset()  # type: ignore[call-arg]
# --> 701             data = self._next_data()
#     702             self._num_yielded += 1
#     703             if (
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     755     def _next_data(self):
#     756         index = self._next_index()  # may raise StopIteration
# --> 757         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758         if self._pin_memory:
#     759             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# <ipython-input-17-7c0c5f3517d9> in __getitem__(self, idx)
#      25
#      26         noisy_img = np.array(Image.open(noisy_path)) / 255.0
# ---> 27         gt_img = np.array(Image.open(gt_path)) / 255.0
#      28
#      29         noisy_img = torch.FloatTensor(noisy_img).permute(2, 0, 1)
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in __array_interface__(self)
#     754             new["data"] = self.tobytes("raw", "L")
#     755         else:
# --> 756             new["data"] = self.tobytes()
#     757         new["shape"], new["typestr"] = _conv_type_shape(self)
#     758         return new
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in tobytes(self, encoder_name, *args)
#     803             encoder_args = self.mode
#     804
# --> 805         self.load()
#     806
#     807         if self.width == 0 or self.height == 0:
#
# /usr/local/lib/python3.10/dist-packages/PIL/ImageFile.py in load(self)
#     298
#     299                             b = b + s
# --> 300                             n, err_code = decoder.decode(b)
#     301                             if n < 0:
#     302                                 break
#
# KeyboardInterrupt:

# %%
# Training SRGAN
def train_sgan(train_loader, val_loader, epochs=100):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    gen = Generator().to(device)
    disc = Discriminator().to(device)
    
    # Load Epoch 20 checkpoint
    checkpoint_path = "srgan_gen_epoch_20.pth"
    try:
        gen.load_state_dict(torch.load(checkpoint_path))
        print(f"Loaded checkpoint from {checkpoint_path}, continuing from Epoch 20")
    except FileNotFoundError:
        print(f"Checkpoint {checkpoint_path} not found—training from scratch")
    
    g_opt = torch.optim.Adam(gen.parameters(), lr=1e-4)
    d_opt = torch.optim.Adam(disc.parameters(), lr=1e-4)
    g_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(g_opt, 'min', patience=5, factor=0.5)
    d_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(d_opt, 'min', patience=5, factor=0.5)
    mse_loss = nn.MSELoss()
    bce_logits_loss = nn.BCEWithLogitsLoss()
    scaler = GradScaler('cuda')

    for epoch in range(20, epochs):  # Start from 21 since loaded Epoch 20
        gen.train()
        disc.train()
        g_loss_total, d_loss_total = 0, 0
        for noisy, gt in train_loader:
            noisy, gt = noisy.to(device), gt.to(device)
            gt_gray = torch.mean(gt, dim=1, keepdim=True)
            
            # Train Discriminator
            d_opt.zero_grad()
            with autocast('cuda'):
                real_out = disc(gt_gray)
                fake_img = gen(noisy)
                fake_out = disc(fake_img.detach())
                d_loss = bce_logits_loss(real_out, torch.ones_like(real_out)) + \
                         bce_logits_loss(fake_out, torch.zeros_like(fake_out))
            scaler.scale(d_loss).backward()
            scaler.step(d_opt)
            scaler.update()
            d_loss_total += d_loss.item()
            
            # Train Generator
            g_opt.zero_grad()
            with autocast('cuda'):
                fake_out = disc(fake_img)
                g_mse = mse_loss(fake_img, gt_gray)
                g_adv = bce_logits_loss(fake_out, torch.ones_like(fake_out))
                g_loss = 0.95 * g_mse + 0.05 * g_adv
            scaler.scale(g_loss).backward()
            scaler.step(g_opt)
            scaler.update()
            g_loss_total += g_mse.item()
        
        avg_g_loss = g_loss_total / len(train_loader)
        avg_d_loss = d_loss_total / len(train_loader)
        print(f"Epoch {epoch+1}/{epochs}, G Loss (MSE): {avg_g_loss:.6f}, D Loss: {avg_d_loss:.6f}")
        
        gen.eval()
        val_loss = 0
        with torch.no_grad():
            for noisy, gt in val_loader:
                noisy, gt = noisy.to(device), gt.to(device)
                with autocast('cuda'):
                    output = gen(noisy)
                    gt_gray = torch.mean(gt, dim=1, keepdim=True)
                    loss = mse_loss(output, gt_gray)
                val_loss += loss.item()
        val_mse = val_loss / len(val_loader)
        val_psnr = 10 * torch.log10(1 / torch.tensor(val_mse)).item()
        print(f"Validation Loss: {val_mse:.6f}, PSNR: {val_psnr:.2f} dB")
        
        g_scheduler.step(val_mse)
        d_scheduler.step(avg_d_loss)
        
        if (epoch + 1) % 10 == 0:
            torch.save(gen.state_dict(), f"srgan_gen_epoch_{epoch+1}.pth")
            print(f"Saved checkpoint: srgan_gen_epoch_{epoch+1}.pth")
    
    torch.save(gen.state_dict(), "srgan_gen_final.pth")
    return gen

# %%
model = train_sgan(train_loader, val_loader, epochs=100)

# %%
model.load_state_dict(torch.load("srgan_gen_epoch_20.pth"))
# Out:
# <ipython-input-37-577406f7fa57>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("srgan_gen_epoch_20.pth"))
# <All keys matched successfully>

# %%
generate_submission(model, test_dir, output_folder, submission_csv)
# Out:
# Successfully saved to submission.csv

# %%
# Training SRGAN
def train_sgan(train_loader, val_loader, epochs=100):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    gen = Generator().to(device)
    disc = Discriminator().to(device)
    
    # Load Epoch 20 checkpoint
    checkpoint_path = "srgan_gen_epoch_20.pth"
    try:
        gen.load_state_dict(torch.load(checkpoint_path))
        print(f"Loaded checkpoint from {checkpoint_path}, continuing from Epoch 20")
    except FileNotFoundError:
        print(f"Checkpoint {checkpoint_path} not found—training from scratch")
    
    g_opt = torch.optim.Adam(gen.parameters(), lr=5e-5)  # Lower LR
    d_opt = torch.optim.Adam(disc.parameters(), lr=5e-5)  # Lower LR
    g_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(g_opt, 'min', patience=5, factor=0.5)
    d_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(d_opt, 'min', patience=5, factor=0.5)
    mse_loss = nn.MSELoss()
    bce_logits_loss = nn.BCEWithLogitsLoss()
    scaler = GradScaler('cuda')

    for epoch in range(20, epochs):
        gen.train()
        disc.train()
        g_loss_total, d_loss_total = 0, 0
        for noisy, gt in train_loader:
            noisy, gt = noisy.to(device), gt.to(device)
            gt_gray = torch.mean(gt, dim=1, keepdim=True)
            
            # Train Discriminator
            d_opt.zero_grad()
            with autocast('cuda'):
                real_out = disc(gt_gray)
                fake_img = gen(noisy)
                fake_out = disc(fake_img.detach())
                d_loss = bce_logits_loss(real_out, torch.ones_like(real_out)) + \
                         bce_logits_loss(fake_out, torch.zeros_like(fake_out))
            scaler.scale(d_loss).backward()
            scaler.step(d_opt)
            scaler.update()
            d_loss_total += d_loss.item()
            
            # Train Generator
            g_opt.zero_grad()
            with autocast('cuda'):
                fake_out = disc(fake_img)
                g_mse = mse_loss(fake_img, gt_gray)
                g_adv = bce_logits_loss(fake_out, torch.ones_like(fake_out))
                g_loss = 0.9 * g_mse + 0.1 * g_adv  # Adjusted weights
            scaler.scale(g_loss).backward()
            scaler.step(g_opt)
            scaler.update()
            g_loss_total += g_mse.item()
        
        avg_g_loss = g_loss_total / len(train_loader)
        avg_d_loss = d_loss_total / len(train_loader)
        print(f"Epoch {epoch+1}/{epochs}, G Loss (MSE): {avg_g_loss:.6f}, D Loss: {avg_d_loss:.6f}")
        
        gen.eval()
        val_loss = 0
        with torch.no_grad():
            for noisy, gt in val_loader:
                noisy, gt = noisy.to(device), gt.to(device)
                with autocast('cuda'):
                    output = gen(noisy)
                    gt_gray = torch.mean(gt, dim=1, keepdim=True)
                    loss = mse_loss(output, gt_gray)
                val_loss += loss.item()
        val_mse = val_loss / len(val_loader)
        val_psnr = 10 * torch.log10(1 / torch.tensor(val_mse)).item()
        print(f"Validation Loss: {val_mse:.6f}, PSNR: {val_psnr:.2f} dB")
        
        g_scheduler.step(val_mse)
        d_scheduler.step(avg_d_loss)
        
        if (epoch + 1) % 10 == 0:
            torch.save(gen.state_dict(), f"srgan_gen_epoch_{epoch+1}.pth")
            print(f"Saved checkpoint: srgan_gen_epoch_{epoch+1}.pth")
    
    torch.save(gen.state_dict(), "srgan_gen_final.pth")
    return gen

# %%
model = train_sgan(train_loader, val_loader, epochs=100)

# %%
generate_submission(model, test_dir, output_folder, submission_csv)
