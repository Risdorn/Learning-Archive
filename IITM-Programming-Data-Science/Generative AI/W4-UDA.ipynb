# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets, transforms
from torchvision.utils import save_image, make_grid

import matplotlib.pyplot as plt
import numpy as np
import os

# %matplotlib inline

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
transform_mnist = transforms.Compose([
    transforms.Resize((28,28)),
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x.repeat(3,1,1)),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

transform_mnist_m = transforms.Compose([
    transforms.Resize((28,28)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

mnist = torchvision.datasets.MNIST(root=".", download=False, train=True, transform=transform_mnist)
mnist_loader = DataLoader(mnist, batch_size=8, shuffle=True)

mnist_m = MNISTM(root=".", download=True, train=True, transform=transform_mnist_m)
mnist_m_loader = DataLoader(mnist_m, batch_size=8, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 17
#      14 mnist = torchvision.datasets.MNIST(root=".", download=False, train=True, transform=transform_mnist)
#      15 mnist_loader = DataLoader(mnist, batch_size=8, shuffle=True)
# ---> 17 mnist_m = MNISTM(root=".", download=True, train=True, transform=transform_mnist_m)
#      18 mnist_m_loader = DataLoader(mnist_m, batch_size=8, shuffle=True)
#
# NameError: name 'MNISTM' is not defined
